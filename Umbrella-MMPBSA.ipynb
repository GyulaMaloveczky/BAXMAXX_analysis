# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Data from the image
from scipy import stats

#from sequence_analysis import umbrella_sampling

first = pd.read_csv("/home/kunzj/report/data/first_df_metrics_md_sim.csv")
second = pd.read_csv("/home/kunzj/report/data/second_df_metrics_md_sim.csv")
third = pd.read_csv("/home/kunzj/report/data/third_df_metrics_md_sim.csv")

#claude_cheap = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/claude_advice/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
#claude_cheap.name = "Medium cost custom"

claude_expensive = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/claude_advice_expensive/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
claude_expensive.name = "High cost custom"

inp_1 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/inp_1/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
inp_1.name = "Default + inp = 1, indi = 5"

inp_2 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/inp_2/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
inp_2.name = "Default + (inp = 2, indi = 5)"

nikki = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki.name = "Advanced 1"

nikki125 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis_indi1.25/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki125.name = "Advanced 1.25"

nikki_higher_dielectric = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis_higher_dielectric/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki_higher_dielectric.name = "Advanced  (indi = 5)"

nikki_higher_dielectric15 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis_indi1.5/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki_higher_dielectric15.name = "Advanced  (indi = 1.5)"

nikki_higher_dielectric2 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis_indi2/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki_higher_dielectric2.name = "Advanced  (indi = 2)"


nikki_higher_dielectric3 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis_indi3/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki_higher_dielectric3.name = "Advanced  (indi = 3)"


nikki_higher_dielectric4 = pd.read_csv("/FastHome/gyula/designs/place_holder/DATA/umbrella_benchmark/nikis_indi4/md_sim_analysis/mmpbsa/jobs/delta_total_summary.csv")
nikki_higher_dielectric4.name = "Advanced  (indi = 4)"





df_list = [inp_1, inp_2, nikki, nikki_higher_dielectric15, nikki_higher_dielectric2, nikki_higher_dielectric3, nikki_higher_dielectric4, nikki_higher_dielectric,  claude_expensive]

# %%
# Out:
#    subdir  delta_total  dG_binding_IE  dG_binding_IE_err
# 0   job_1       -47.36          13.88               7.10
# 1  job_34       -57.85          21.16               7.70
# 2   job_9       -51.13          22.47               8.37
# 3  job_91       -76.34          10.19               7.14

# %%
plt.scatter(umbrella_sampling, [12, 10, 14, 15])

# %%
plt.close()
entries = [1,  34, 9, 91]
umbrella_sampling = [-19.53,  -21.93, -21.77, -27.56]


# Create scatterplot
for df in df_list:
    entries = entries[0:4]
    x = umbrella_sampling[0:4]
    y = df.iloc[0:4, -3]

    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, c='blue', s=100, alpha=0.7)

    for i, entry in enumerate(entries):
        plt.annotate(f'Entry {entry}',
                     (x[i], y[i]),
                     textcoords="offset points",
                     xytext=(5, 5),
                     ha='center')

    plt.xlabel('Umbrella Sampling (kcal/mol)', fontsize=12)
    plt.ylabel('MM-PBSA (kcal/mol)', fontsize=12)
    plt.title(str(df.name), fontsize=14)
    plt.grid(True, alpha=0.3)

    r, p = stats.pearsonr(x, y)

    plt.text(0.05, 0.95, f"r = {r:.2f}, p = {p:.3f}", transform=plt.gca().transAxes, verticalalignment='top')

    # Add a diagonal line for reference
    min_val = min(min(x), min(y))
    max_val = max(max(x), max(y))
    plt.plot([min(x), max(x)], [ min(y), max(y)], 'r--', alpha=0.5, label='y=x')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# Out:
# (array([0, 1, 2, 3]),)

# %%
j_mmpbsa = []
j_mmpbsa.append(first.iloc[0, -1])
j_mmpbsa.append(first.iloc[33, -1])
j_mmpbsa.append(first.iloc[8, -1])
j_mmpbsa.append(first.iloc[90, -1])


df = df_list[0]
entries = entries[0:4]
x = j_mmpbsa[0:4]
y = df.iloc[0:4, -1]

plt.figure(figsize=(8, 6))
plt.scatter(x, y, c='blue', s=100, alpha=0.7)

for i, entry in enumerate(entries):
    plt.annotate(f'Entry {entry}',
                 (x[i], y[i]),
                 textcoords="offset points",
                 xytext=(5, 5),
                 ha='center')

plt.xlabel('Umbrella Sampling (kcal/mol)', fontsize=12)
plt.ylabel('MM-PBSA (kcal/mol)', fontsize=12)
plt.title(str(df.name), fontsize=14)
plt.grid(True, alpha=0.3)

# Add a diagonal line for reference
min_val = min(min(x), min(y))
max_val = max(max(x), max(y))
plt.plot([min(x), max(x)], [ min(y), max(y)], 'r--', alpha=0.5, label='y=x')
plt.legend()

r, p = stats.pearsonr(x, y)

plt.text(0.05, 0.95, f"r = {r:.2f}, p = {p:.3f}", transform=plt.gca().transAxes, verticalalignment='top')

plt.text(0.05, 0.95, f"r = {r:.2f}, p = {p:.3f}", transform=plt.gca().transAxes, verticalalignment='top')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5 j_mmpbsa.append(first.iloc[90, -1])
#       6
#       7
#       8 df = df_list[0]
# ----> 9 entries = entries[0:4]
#      10 x = j_mmpbsa[0:4]
#      11 y = df.iloc[0:4, -1]
#      12
#
# NameError: name 'entries' is not defined
