# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("/FastHome/gyula/designs/gy_0/final_design_stats.csv")

# %%
df
# Out:
#      Rank                      Design Protocol  Length    Seed  Helicity  \
# 0       1  BAX_1F16_l12_s733843_mpnn1   3stage      12  733843      0.95
# 1       2  BAX_1F16_l12_s733843_mpnn2   3stage      12  733843      0.95
# 2       3   BAX_1F16_l16_s59065_mpnn2   3stage      16   59065      0.95
# 3       4  BAX_1F16_l23_s825601_mpnn2   3stage      23  825601      0.95
# 4       5  BAX_1F16_l22_s698645_mpnn1   3stage      22  698645      0.95
# ..    ...                         ...      ...     ...     ...       ...
# 98     99  BAX_1F16_l16_s880196_mpnn3   3stage      16  880196      0.95
# 99    100  BAX_1F16_l17_s854467_mpnn2   3stage      17  854467      0.95
# 100   101  BAX_1F16_l17_s854467_mpnn1   3stage      17  854467      0.95
# 101   102   BAX_1F16_l21_s70442_mpnn2   3stage      21   70442      0.95
# 102   103   BAX_1F16_l21_s70442_mpnn1   3stage      21   70442      0.95
#
#     Target_Hotspot                 Sequence  \
# 0            74-99             DPKKVAEFLRSW
# ...

# %%
sns.scatterplot(x = df["Length"], y = df["Average_i_pTM"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.corrcoef(df["Length"], df["Average_i_pTM"])
# Out:
# array([[ 1.       , -0.2757792],
#        [-0.2757792,  1.       ]])
